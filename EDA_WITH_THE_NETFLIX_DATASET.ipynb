# %% [markdown]
# # DATA ANALYSIS OF THE NETFLIX DATA SET

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
df=pd.read_csv("/content/file (1).csv")
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# Basic information of the data set

# %%
def get_basic(df):
  return(
      "******INFO*******",df.info(),
      "*******First five rows*****",df.head(),
      "******Sample Rows",df.sample(),
      "*****Statics of Data Frame",df.describe(),
      "****Shape of Data Frame ",df.shape,
       "*******Columns******",df.columns,
      "********D types******",df.dtypes)

# %%
get_basic(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB
# ('******INFO*******',
#  None,
#  '*******First five rows*****',
#    Show_Id Category  Title           Director  \
#  0      s1  TV Show     3%                NaN
#  1      s2    Movie  07:19  Jorge Michel Grau
#  2      s3    Movie  23:59       Gilbert Chan
# ...

# %% [markdown]
# Find duplicates in the data set and revome the duplicates also

# %%
duplicate=df[(df.duplicated())]
#there are the two Duplicates in the data set
duplicate
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# To drop the duplicate values in the data Frame

# %%
df=df.drop_duplicates()
df.duplicated().sum()
#know there are NO duplicate records in the data frame
# Out:
# 0

# %% [markdown]
# #There are any null values show with the HEAT MAP

# %% [markdown]
# NULL VALUES

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# Showing the null values by the heat map

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# For house of card what is show id and who is the director of the show ?

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df[(df["Title"].isin(["House of Cards"]))]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df["Title"].str.contains("House of Cards")]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # In Which year the highest TV shows and movies were released show with the bargraph

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df["date"]=pd.to_datetime(df["Release_Date"])

# %%
df["year"]=df["date"].dt.year
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       date    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df["year"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# How many TV shows and Movies in the data set

# %%
df.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# ploting bar graph of the dataset conting TVshows and Movies

# %%
df["Category"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# Show all the movies which where released in the year 2000

# %%
df.head(75)
# Out:
#    Show_Id Category                                  Title  \
# 0       s1  TV Show                                     3%
# 1       s2    Movie                                  07:19
# 2       s3    Movie                                  23:59
# 3       s4    Movie                                      9
# 4       s5    Movie                                     21
# ..     ...      ...                                    ...
# 70     s71    Movie                  14 Minutes from Earth
# 71     s72    Movie                              16 Blocks
# 72     s73    Movie                               17 Again
# 73     s74    Movie                            18 Presents
# 74     s75    Movie  1898: Our Last Men in the Philippines
#
#                                              Director  \
# 0                                                 NaN
# 1                                   Jorge Michel Grau
# 2                                        Gilbert Chan
# ...

# %%
df[(df["Category"]=="Movies")&(df["year"]==2000)]
#So there where no movies where released in the year 2000
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date, year]
# Index: []

# %% [markdown]
# Show all the title of all the TV shows where released in the india

# %%
df[(df["Category"]=="TV Show") & (df["Country"]=="India")]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# Show the higheat number of directors who gave the highest number of TV shows and movies in the netfilx

# %%
df.head()
df["Director"].value_counts()[0:5]
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Name: Director, dtype: int64

# %% [markdown]
# Show all the records where the categories is the movies and typecomidies or the country is unites kingdom

# %%
df[((df["Category"]=="Movie") & (df["Type"]=="Comedies")|(df["Type"]=="United States"))]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %% [markdown]
# IN how many movies and shows TOM CRUSE was cast

# %%
df[(df["Cast"]=="Tom Cruise")]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date, year]
# Index: []

# %%
new_data=df.dropna()
new_data
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
new_data[(new_data["Cast"].str.contains("Tom Cruise"))]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       date    year  \
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0
#
#                                                new_cast
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...
# ...

# %% [markdown]
# What are the different Rating Defined by netflix

# %%
df.head()
df["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df["Rating"].nunique()
# Out:
# 14

# %% [markdown]
# How many movies got TV 14 rating in the canada

# %%
df[(df["Rating"]=="TV-14" )& (df["Country"]=="Canada")]["Title"]
# Out:
# 30                                 #cats_the_mewvie
# 34                                            #Roxy
# 608                                  At First Light
# 791                              Beauty & the Beast
# 862                                         Between
# 994                                      Blown Away
# 1047          Border Security: America's Front Line
# 1506                     Counterfeiting in Suburbia
# 1687                           Degrassi: Next Class
# 2678                                      Heartland
# 3713                              Long Time Running
# 3730                                      Lost Girl
# 3956    Martin Matte: La vie, la mort...eh la la..!
# 4513                                Northern Rescue
# 4769                            Paranormal Survivor
# 5165                              Republic of Doyle
# 5170                        Restaurants on the Edge
# 5318                          Rust Valley Restorers
# ...

# %% [markdown]
# how many movies got the R rating at the year 2018

# %%
df[(df["Rating"]=="R") & (df["year"]==2018)].shape[0]
# Out:
# 131

# %% [markdown]
# What is the Maximum duration of movie or TV show on the netfix

# %%
df["Duration"].value_counts()
# Out:
# 1 Season     1608
# 2 Seasons     382
# 3 Seasons     184
# 90 min        136
# 93 min        131
#              ...
# 182 min         1
# 224 min         1
# 233 min         1
# 196 min         1
# 191 min         1
# Name: Duration, Length: 216, dtype: int64

# %%
df[["min","units"]]=df["Duration"].str.split(" ",expand=True)

# %%
df["min"].max()
# Out:
# '99'

# %% [markdown]
# Indudival country has the highest number of TV shows

# %%
df[(df["Category"]=="TV Show")].Country.value_counts()[0:1]
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# How to sort the data set by the year

# %%
df.sort_values("year", ascending=False).head()
# Out:
#      Show_Id Category             Title                 Director  \
# 5564   s5564    Movie   Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie         Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show      Bling Empire                      NaN
# 5955   s5955    Movie  Taare Zameen Par               Aamir Khan
# 366     s367    Movie         Al acecho      Francisco D'Eufemia
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 5955  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                                                 Country      Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia   January 1, 2021
# 5919                                      United States   January 1, 2021
# ...

# %% [markdown]
# Find all the instance where the categories is movie and type is dramas

# %%
df[(df["Category"]=="Movie" )& (df["Type"]=="Dramas")]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df.sample(12)
# Out:
#      Show_Id Category                   Title                Director  \
# 4223   s4224    Movie             Moonwalkers  Antoine Bardou-Jacquet
# 1362   s1363    Movie      Christmas Break-In           Michael Kampa
# 6484   s6483  TV Show       The InBESTigators                     NaN
# 474     s475    Movie            American Son              Kenny Leon
# 3818   s3819  TV Show            Luna Petunia                     NaN
# 7027   s7026  TV Show                The Yard                     NaN
# 3569   s3570    Movie                  Legend         Brian Helgeland
# 1373   s1374    Movie       Christopher Robin            Marc Forster
# 5554   s5554    Movie  She Made Me a Criminal               Amr Arafa
# 758     s759    Movie          Basic Instinct          Paul Verhoeven
# 5991   s5991    Movie                  Tattah         Sameh Abdulaziz
# 2030   s2031  TV Show            Eternal Love                     NaN
#
# ...

# %% [markdown]
# Rows which contains the Category as TV shows and Type is Kids TV

# %%
df[(df["Category"]=="TV Show") & (df["Type"]=="Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...
